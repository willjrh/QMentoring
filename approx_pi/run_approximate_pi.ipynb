# %% [markdown]
# # A notebook to run approximate $\pi$

# %% [markdown]
# First we do the imports

# %%
# some packages we will use, not the approximate pi code
import pandas as pd
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook_connected'
import numpy as np
# the three implementations of the approximate pi code
from approximate_pi import approximate_pi_loop, approximate_pi_comp, approximate_pi_figure

# this automatically picks up any changes in the modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **The first implementation with a loop**

# %%
pi_loop = approximate_pi_loop(1_000_000)
print(f"We approximated pi as {pi_loop}, with error {100*(1 - np.pi/pi_loop):.2f}%")
# Out:
# We approximated pi as 3.14214, with error 0.02%

# %% [markdown]
# **The second implementation with a comprehension**

# %%
pi_comp = approximate_pi_comp(1_000_000)
print(f"We approximated pi as {pi_comp}, with error {100*(1 - np.pi/pi_comp):.2f}%")
# Out:
# We approximated pi as 3.140512, with error -0.03%

# %% [markdown]
# **The third implementation with a plot**
#
# The $\pi$ calculation is the same as the on for in the loop

# %%
pi_fig, pi_data = approximate_pi_figure(1_000)
print(f"We approximated pi as {pi_fig}, with error {100*(1 - np.pi/pi_fig):.2f}%")
# Out:
# We approximated pi as 3.18, with error 1.21%

# %% [markdown]
# Now we will plot some of the data. First we will convert the dictionary into a Pandas DataFrame, see [Pandas](https://pandas.pydata.org/)

# %%
pi_df = pd.DataFrame(pi_data)
display(pi_df)
# Out:
#            xs        ys location
# 0    0.616960  0.598241       in
# 1    0.109372  0.211462       in
# 2    0.461634  0.217580       in
# 3    0.961303  0.178330       in
# 4    0.255790  0.165419       in
# ..        ...       ...      ...
# 995  0.739805  0.219048       in
# 996  0.794749  0.728898      out
# 997  0.614002  0.555057       in
# 998  0.070664  0.591274       in
# 999  0.734706  0.972357      out
#
# [1000 rows x 3 columns]

# %% [markdown]
# Now we can plot this data:

# %%
fig = px.scatter(pi_df, x="xs", y="ys", color="location", range_x=[0,1], range_y=[0,1], width=600, height=600)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="b20c53db-bdd6-4a96-9e2f-bf7b93cae71d" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b20c53db-bdd6-4a96-9e2f-bf7b93cae71d")) {                    Plotly.newPlot(                        "b20c53db-bdd6-4a96-9e2f-bf7b93cae71d",                        [{"hovertemplate":"location=in<br>xs=%{x}<br>ys=%{y}<extra></extra>","legendgroup":"in","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"in","orientation":"v","showlegend":true,"x":[0.6169596340483753,0.10937169177994466,0.4616344388794257,0.9613026794744126,0.25578999576779726,0.4316532972270103,0.3077046838188269,0.844920652379444,0.5183128992251995,0.35068699303881257,0.2370850455392629,0.44694339894988877,0.711048510523647,0.037212171198607424,0.15013495285149459,0.826273683429245,0.005707147342951746,0.16540549793299764,0.3585428469994534,0.3835619677226202,0.49841118400002093,0.10953596990244452,0.6244367777776723,0.3779105360093171,0.12860122766227733,0.6411092869019582,0.5381391099308378,0.6285730259360418,0.7438897513252191,0.6581398419091207,0.5498451705016686,0.016233085337381215,0.4294346845109335,0.6704388905844982,0.6194603739073113,0.831999030339576,0.4965914781152685,0.5697364707543546,0.7632885945710857,0.3610948182917916,0.6588666105976057,0.41969890333595583,0.30782414606154396,0.17621444681747167,0.4648052168462453,0.5273354762106958,0.8734789830445095,0.27949316392388135,0.05832187983455772,0.9670397226558638,0.6159875881362837,0.4227385733946346,0.5417837920580603,0.00814767356305246,0.2885433316373456,0.5593476231642474,0.8002578106877527,0.13230609740232535,0.12138959856514131,0.6095644117889802,0.3578872089824331,0.8171688639247238,0.5340401183609171,0.15103775475629555,0.8725424311612578,0.3963666309938032,0.5164575000996531,0.3674656297902186,0.5215034786963164,0.8889650360062771,0.6300778071537358,0.26617799393798103,0.2742954057381529,0.18144751466944065,0.07325764179100669,0.38672324606346054,0.7962142308145753,0.6371656051239336,0.3546549638159977,0.818908140823062,0.7979529178053129,0.09846748817390805,0.945689243058882,0.00404348127307641,0.44900320148828143,0.06308946264479054,0.7493248315325581,0.00945741232501529,0.5731775978284959,0.34631290234362444,0.05365597472262418,0.48370194007967426,0.4178777022780713,0.5345568561844697,0.5249233658539264,0.5379649540943741,0.4498374203672326,0.03297883922387401,0.4916332788622132,0.7617815933093527,0.6116304215387115,0.39697957270935846,0.14243185405169323,0.5725867768544514,0.7788476472735137,0.15192321085056326,0.26187927551930634,0.6271216064921724,0.25087495178708896,0.28378402382255563,0.4920413220496028,0.005910003665962171,0.03357829472091489,0.6303705425556106,0.27676619415202286,0.9734498253230885,0.5279303780374556,0.4523965058345507,0.11259691855847909,0.598655811345507,0.5253811104795276,0.3830863789307688,0.501677675598964,0.7856573237531358,0.477174833889597,0.21169598452841243,0.4963581057027562,0.06547932240473531,0.16188859053014393,0.26284485216532893,0.001480285249756741,0.9702664476267145,0.77253125724027,0.029448384055630994,0.8921524020468624,0.5234025542641524,0.8864236079926883,0.7792692318742104,0.2712381658827572,0.3193774012920737,0.18298415648476118,0.27252637191251894,0.1790415936817461,0.14966970153301395,0.3681652507400117,0.6173349712809587,0.550927174258002,0.15694669358110103,0.5694174739689384,0.07413524749878153,0.5709104161240448,0.36922949756754564,0.7397366190720777,0.5915236917217703,0.4432526916985532,0.37363896474706204,0.609080661527785,0.14570929466766536,0.0974973166427443,0.5308777464810184,0.5245975360485896,0.6654299179046945,0.9563388522471068,0.1214027117533818,0.5548083675201955,0.05839174463255914,0.5563939227161587,0.6723304760058745,0.03327021720706602, ...
